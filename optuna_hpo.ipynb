# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
# from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import optuna
# import optuna.visualization as vis
# import plotly
from optuna.samplers import RandomSampler
from optuna_dashboard import run_server
from sklearn.model_selection import learning_curve

# %%
pub = pd.read_csv('data/public_data.csv')
submit_pd = pd.read_csv('data/minta_beadando_rand.csv')

# %%
pub.head()
# Out:
#    rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 0      0       1        18              0     0       0    False        2
# 1      1       1        18              0     0      15    False        2
# 2      2       1        18              0     0      30    False        2
# 3      3       1        18              0     0      45    False        2
# 4      4       1        18              0     1       0    False        2
#
#            ke      hupx  afrr_fel     afrr_le  mfrr_fel  mfrr_le        afrr  \
# 0  899.343121  287.7194    0.0000 -103.196933       0.0      0.0 -212.845947
# 1  899.374587  287.7194   55.9286   -5.617200       0.0      0.0  263.427160
# 2  899.303875  287.7194   69.6826   -9.355800       0.0      0.0  273.927320
# 3  899.299787  287.7194   30.2718  -16.943567       0.0      0.0  132.621040
# 4  897.436947  283.6309   25.9714  -12.064167       0.0      0.0  151.888080
#
#    solar_becsult_dayahead  rendszerterheles_terv  target_flag  target_reg
# 0                     0.0            6514.140945          0.0 -100.188708
# 1                     0.0            6482.184545          0.0 -100.292441
# 2                     0.0            6310.363525          0.0 -100.059327
# 3                     0.0            6158.798885          0.0 -100.045850
# 4                     0.0            6137.148085          0.0 -104.954619

# %%
df = pub.copy()
df.head()
# Out:
#    rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 0      0       1        18              0     0       0    False        2
# 1      1       1        18              0     0      15    False        2
# 2      2       1        18              0     0      30    False        2
# 3      3       1        18              0     0      45    False        2
# 4      4       1        18              0     1       0    False        2
#
#            ke      hupx  afrr_fel     afrr_le  mfrr_fel  mfrr_le        afrr  \
# 0  899.343121  287.7194    0.0000 -103.196933       0.0      0.0 -212.845947
# 1  899.374587  287.7194   55.9286   -5.617200       0.0      0.0  263.427160
# 2  899.303875  287.7194   69.6826   -9.355800       0.0      0.0  273.927320
# 3  899.299787  287.7194   30.2718  -16.943567       0.0      0.0  132.621040
# 4  897.436947  283.6309   25.9714  -12.064167       0.0      0.0  151.888080
#
#    solar_becsult_dayahead  rendszerterheles_terv  target_flag  target_reg
# 0                     0.0            6514.140945          0.0 -100.188708
# 1                     0.0            6482.184545          0.0 -100.292441
# 2                     0.0            6310.363525          0.0 -100.059327
# 3                     0.0            6158.798885          0.0 -100.045850
# 4                     0.0            6137.148085          0.0 -104.954619

# %%
pub = pd.read_csv('data/public_data.csv')

def f(x):
    if x == 4:
        return "submit"
    elif x == 3:
        return "test"
    else:
        return "train"
    
df['train_test_validation']=df['day_in_period'].apply(f)

# %%
df['periodID'].nunique()
# Out:
# 187

# %%
input_variables = ['hour', 'minute', 'holyday', 'weekday', 'ke','hupx',	'afrr_fel',	'afrr_le',	'mfrr_fel',	'mfrr_le',	'afrr',	'solar_becsult_dayahead','rendszerterheles_terv']

# %%
train_df = df[df['train_test_validation'] == 'train']
test_df = df[df['train_test_validation'] == 'test']
submit_df = df[df['train_test_validation'] == 'submit']

# %%
print(train_df)
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 0          0       1        18              0     0       0    False        2
# 1          1       1        18              0     0      15    False        2
# 2          2       1        18              0     0      30    False        2
# 3          3       1        18              0     0      45    False        2
# 4          4       1        18              0     1       0    False        2
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89563  93068      11       194              2    22      45    False        6
# 89564  93069      11       194              2    23       0    False        6
# 89565  93070      11       194              2    23      15    False        6
# 89566  93071      11       194              2    23      30    False        6
# 89567  93072      11       194              2    23      45    False        6
#
#                ke      hupx  afrr_fel     afrr_le  mfrr_fel  mfrr_le  \
# 0      899.343121  287.7194    0.0000 -103.196933       0.0      0.0
# 1      899.374587  287.7194   55.9286   -5.617200       0.0      0.0
# 2      899.303875  287.7194   69.6826   -9.355800       0.0      0.0
# 3      899.299787  287.7194   30.2718  -16.943567       0.0      0.0
# 4      897.436947  283.6309   25.9714  -12.064167       0.0      0.0
# ...           ...       ...       ...         ...       ...      ...
# 89563  797.324260  242.2464    0.1924  -62.691300       0.0      0.0
# 89564  940.699013  238.1061   13.5252  -43.374167       0.0      0.0
# 89565  937.938811  238.1061  188.1230   -1.420833       0.0      0.0
# 89566  934.909104  238.1061  126.3730   -0.094033       0.0      0.0
# 89567  928.262517  238.1061   80.6520   -0.179800       0.0      0.0
#
#              afrr  solar_becsult_dayahead  rendszerterheles_terv  target_flag  \
# 0     -212.845947                     0.0            6514.140945          0.0
# 1      263.427160                     0.0            6482.184545          0.0
# 2      273.927320                     0.0            6310.363525          0.0
# 3      132.621040                     0.0            6158.798885          0.0
# 4      151.888080                     0.0            6137.148085          0.0
# ...           ...                     ...                    ...          ...
# 89563 -171.740207                     0.0            5055.460670          1.0
# 89564  -68.458280                     0.0            5031.828980          0.0
# 89565  608.230560                     0.0            5013.521850          0.0
# 89566  467.144080                     0.0            4997.670587          0.0
# 89567  356.189040                     0.0            4983.557263          0.0
#
#        target_reg train_test_validation
# 0     -100.188708                 train
# 1     -100.292441                 train
# 2     -100.059327                 train
# 3     -100.045850                 train
# 4     -104.954619                 train
# ...           ...                   ...
# 89563  113.237209                 train
# 89564 -370.616813                 train
# 89565 -361.517248                 train
# 89566 -351.529201                 train
# 89567 -329.617377                 train
#
# [53856 rows x 20 columns]

# %%
print(test_df)
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 288      288       1        18              3     0       0    False        5
# 289      289       1        18              3     0      15    False        5
# 290      290       1        18              3     0      30    False        5
# 291      291       1        18              3     0      45    False        5
# 292      292       1        18              3     1       0    False        5
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89659  93164      11       194              3    22      45    False        0
# 89660  93165      11       194              3    23       0    False        0
# 89661  93166      11       194              3    23      15    False        0
# 89662  93167      11       194              3    23      30    False        0
# 89663  93168      11       194              3    23      45    False        0
#
#                ke      hupx  afrr_fel     afrr_le  mfrr_fel  mfrr_le  \
# 288    818.432049  254.4823    0.0000 -166.681833       0.0      0.0
# 289    821.300604  254.4823    3.7986  -25.764100       0.0      0.0
# 290    821.300418  254.4823    0.0000  -52.983133       0.0      0.0
# 291    821.300604  254.4823    0.0000 -115.675467       0.0      0.0
# 292    827.623523  251.2670    0.0000 -189.880167       0.0      0.0
# ...           ...       ...       ...         ...       ...      ...
# 89659  798.111149  245.0325   48.5940   -4.068233       0.0      0.0
# 89660  955.757579  242.8421    7.5478  -23.976433       0.0      0.0
# 89661  955.062473  242.8421   70.2754   -0.058900       0.0      0.0
# 89662  798.423227  242.8421   13.5954   -8.259433       0.0      0.0
# 89663  797.800393  242.8421   10.8498  -11.153800       0.0      0.0
#
#              afrr  solar_becsult_dayahead  rendszerterheles_terv  target_flag  \
# 288   -277.150007                     0.0            6449.113965          1.0
# 289     15.072000                     0.0            6358.788545          1.0
# 290   -159.524560                     0.0            6264.255005          1.0
# 291   -225.485493                     0.0            6148.678605          1.0
# 292   -300.647673                     0.0            6143.636545          1.0
# ...           ...                     ...                    ...          ...
# 89659  255.125000                     0.0            5290.121743          1.0
# 89660   34.992160                     0.0            5260.683360          0.0
# 89661  331.860320                     0.0            5233.595753          0.0
# 89662  145.118240                     0.0            5208.690177          1.0
# 89663  120.896280                     0.0            5185.924820          1.0
#
#        target_reg train_test_validation
# 288     76.721089                  test
# 289     67.264315                  test
# 290     67.264929                  test
# 291     67.264315                  test
# 292     37.729526                  test
# ...           ...                   ...
# 89659  118.173067                  test
# 89660 -407.460437                  test
# 89661 -405.168878                  test
# 89662  111.224239                  test
# 89663  113.277540                  test
#
# [17952 rows x 20 columns]

# %%
print(submit_df)
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 384      384       1        18              4     0       0    False        6
# 385      385       1        18              4     0      15    False        6
# 386      386       1        18              4     0      30    False        6
# 387      387       1        18              4     0      45    False        6
# 388      388       1        18              4     1       0    False        6
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89755  93260      11       194              4    22      45    False        1
# 89756  93261      11       194              4    23       0    False        1
# 89757  93262      11       194              4    23      15    False        1
# 89758  93263      11       194              4    23      30    False        1
# 89759  93264      11       194              4    23      45    False        1
#
#        ke  hupx  afrr_fel  afrr_le  mfrr_fel  mfrr_le  afrr  \
# 384   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 385   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 386   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 387   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 388   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# ...    ..   ...       ...      ...       ...      ...   ...
# 89755 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89756 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89757 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89758 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89759 NaN   NaN       NaN      NaN       NaN      NaN   NaN
#
#        solar_becsult_dayahead  rendszerterheles_terv  target_flag  target_reg  \
# 384                       0.0            5269.072857          NaN         NaN
# 385                       0.0            5254.072107          NaN         NaN
# 386                       0.0            5236.946580          NaN         NaN
# 387                       0.0            5228.023347          NaN         NaN
# 388                       0.0            5238.872100          NaN         NaN
# ...                       ...                    ...          ...         ...
# 89755                     0.0            5256.726477          NaN         NaN
# 89756                     0.0            5228.971040          NaN         NaN
# 89757                     0.0            5203.779573          NaN         NaN
# 89758                     0.0            5180.754317          NaN         NaN
# 89759                     0.0            5159.795830          NaN         NaN
#
#       train_test_validation
# 384                  submit
# 385                  submit
# 386                  submit
# 387                  submit
# 388                  submit
# ...                     ...
# 89755                submit
# 89756                submit
# 89757                submit
# 89758                submit
# 89759                submit
#
# [17952 rows x 20 columns]

# %%
"""
randF_C = RandomForestClassifier(random_state=42,
                                 n_estimators=33,
                                 max_depth=7)
"""
"""
randF_R = RandomForestRegressor(random_state=42,
                            n_estimators=33,
                            max_depth=7)
"""
# Out:
# '\nrandF_R = RandomForestRegressor(random_state=42,\n                            n_estimators=33,\n                            max_depth=7)\n'

# %%
# actual old training
# randF_C.fit(train_df[input_variables],train_df['target_flag'])

param_grid = {
    
    #'n_estimators' : [15, 33, 50, 100, 150],
    #'max_depth' : [None, 7, 10, 15, 20],
    #'min_samples_leaf' : [1, 2, 4, 8],
    #'max_features' : [None, 'auto', 'sqrt', 'log2']
    
    # 'n_estimators': [15, 33, 50],
    # 'max_depth': [None, 7, 10],
    # 'min_samples_leaf': [1, 2],
    #'max_features': [None, 'auto']
    
    # 'n_estimators': [15, 33, 50, 100],
    # 'criterion': ['gini', 'entropy'],
    # 'max_depth': [7, 10, 15],
    # 'min_samples_leaf': [1, 2, 4],
    # 'min_weight_fraction_leaf': [0.0, 0.1, 0.2, 0.3, 0.4],
    # 'max_features': ['sqrt', 'log2', None],
    # 'max_leaf_nodes': [None, 10, 20, 30, 40],
}
# rf = RandomForestClassifier(random_state=42)
# grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

#randF_R.fit(train_df[input_variables],train_df['target_reg'])

# %%
# grid_search.fit(train_df[input_variables],train_df['target_flag'])
# best_rf = grid_search.best_estimator_

# %%
# print(grid_search.best_params_)
# best_rf = grid_search.best_estimator_
# print(best_rf)

# gridsearch training
# best_rf = RandomForestClassifier(random_state=42, min_impurity_decrease=0.2, n_estimators=300, max_depth=200, min_samples_leaf = 50, max_features = 'sqrt', max_leaf_nodes=100, ccp_alpha=0.0, criterion='gini', min_weight_fraction_leaf=0.5)
# best_rf.fit(train_df[input_variables],train_df['target_flag'])

# %%
"""
Optuna objective definition
"""
def objective(trial):
    """
    n_estimators = trial.suggest_int('n_estimators', 1, 30)
    max_depth = trial.suggest_int('max_depth', 1, 30)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 150)
    max_features = trial.suggest_categorical(name="max_features", choices=['sqrt', 'log2'])
    ccp_alpha = 0.5
    class_weight = trial.suggest_categorical(name="class_weight", choices=['balanced', 'balanced_subsample'])
    min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 1.0)
    
    hpo_rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_leaf=min_samples_leaf, class_weight = class_weight, max_features=max_features, ccp_alpha=ccp_alpha, random_state=42)
    hpo_rf.fit(train_df[input_variables],train_df['target_flag'])
    
    mean_cv_accuracy = cross_val_score(hpo_rf, train_df[input_variables], train_df['target_flag'], cv=3, n_jobs=-1, scoring='f1_weighted').sum()
    return mean_cv_accuracy
    """
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 150)
    max_depth = trial.suggest_int('max_depth', 5, 50)
    min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
    ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.05)
    max_features = trial.suggest_categorical(name="max_features", choices=['sqrt', 'log2'])
      
    hpo_rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_leaf=min_samples_leaf, ccp_alpha=ccp_alpha, min_impurity_decrease=min_impurity_decrease, max_features=max_features, random_state=42)
    mean_cv_accuracy = cross_val_score(hpo_rf, train_df[input_variables], train_df['target_flag'], cv=3, n_jobs=-1, scoring='roc_auc').mean()
    return mean_cv_accuracy

# %%
"""
Optuna study
"""

db_storage = "sqlite:///db.sqlite3"
current_datetime = datetime.datetime.now()
study_name = f"random_forest_classifier{current_datetime.strftime('%Y-%m-%d_%H-%M-%S')}"
study = optuna.create_study(
    direction="maximize",
    storage=db_storage,  # Specify the storage URL here.
    study_name=study_name,
    pruner=optuna.pruners.MedianPruner(
        n_startup_trials=5, n_warmup_steps=30, interval_steps=10
    ),
)
study.optimize(objective, n_trials=500, n_jobs=-1)

trial = study.best_trial
print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2024-12-10 00:02:43,980] A new study created in RDB with name: random_forest_classifier2024-12-10_00-02-43
# [I 2024-12-10 00:02:47,579] Trial 0 finished with value: 0.956326599827598 and parameters: {'n_estimators': 134, 'min_samples_leaf': 72, 'max_depth': 14, 'min_impurity_decrease': 0.08194205987627387, 'ccp_alpha': 0.012582773541192728, 'max_features': 'log2'}. Best is trial 0 with value: 0.956326599827598.
# [I 2024-12-10 00:02:47,660] Trial 2 finished with value: 0.9649483345113065 and parameters: {'n_estimators': 134, 'min_samples_leaf': 142, 'max_depth': 20, 'min_impurity_decrease': 0.026848698037271135, 'ccp_alpha': 0.044652948575297446, 'max_features': 'log2'}. Best is trial 2 with value: 0.9649483345113065.
# [I 2024-12-10 00:02:48,391] Trial 1 finished with value: 0.9551230878602635 and parameters: {'n_estimators': 181, 'min_samples_leaf': 43, 'max_depth': 38, 'min_impurity_decrease': 0.045884846445267524, 'ccp_alpha': 0.007610578495906517, 'max_features': 'log2'}. Best is trial 2 with value: 0.9649483345113065.
# [I 2024-12-10 00:02:49,655] Trial 5 finished with value: 0.9571088933987119 and parameters: {'n_estimators': 98, 'min_samples_leaf': 119, 'max_depth': 15, 'min_impurity_decrease': 0.05363451230640707, 'ccp_alpha': 0.017840572188928927, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.9649483345113065.
# [I 2024-12-10 00:02:50,873] Trial 8 finished with value: 0.9583579789195621 and parameters: {'n_estimators': 62, 'min_samples_leaf': 116, 'max_depth': 27, 'min_impurity_decrease': 0.06143414218141039, 'ccp_alpha': 0.01516998925224577, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.9649483345113065.
# [I 2024-12-10 00:02:53,181] Trial 4 finished with value: 0.956635210420906 and parameters: {'n_estimators': 238, 'min_samples_leaf': 45, 'max_depth': 15, 'min_impurity_decrease': 0.07624006056410726, 'ccp_alpha': 0.03355959437254959, 'max_features': 'log2'}. Best is trial 2 with value: 0.9649483345113065.
# [I 2024-12-10 00:02:53,605] Trial 9 finished with value: 0.9693233657976302 and parameters: {'n_estimators': 261, 'min_samples_leaf': 116, 'max_depth': 42, 'min_impurity_decrease': 0.011375279460845922, 'ccp_alpha': 0.041582514972740445, 'max_features': 'sqrt'}. Best is trial 9 with value: 0.9693233657976302.
# [I 2024-12-10 00:02:53,869] Trial 10 finished with value: 0.9562640547351077 and parameters: {'n_estimators': 158, 'min_samples_leaf': 8, 'max_depth': 42, 'min_impurity_decrease': 0.08449015690315616, 'ccp_alpha': 0.03994582525554405, 'max_features': 'sqrt'}. Best is trial 9 with value: 0.9693233657976302.
# [I 2024-12-10 00:02:54,343] Trial 11 finished with value: 0.9583579789195621 and parameters: {'n_estimators': 63, 'min_samples_leaf': 95, 'max_depth': 15, 'min_impurity_decrease': 0.06407380368407838, 'ccp_alpha': 0.002831874603150708, 'max_features': 'log2'}. Best is trial 9 with value: 0.9693233657976302.
# [I 2024-12-10 00:02:55,801] Trial 3 finished with value: 0.9838668885756813 and parameters: {'n_estimators': 261, 'min_samples_leaf': 92, 'max_depth': 36, 'min_impurity_decrease': 0.0001798517556252377, 'ccp_alpha': 0.0019436462344904982, 'max_features': 'log2'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:02:56,865] Trial 7 finished with value: 0.9660470367201555 and parameters: {'n_estimators': 118, 'min_samples_leaf': 107, 'max_depth': 40, 'min_impurity_decrease': 0.01494739549526254, 'ccp_alpha': 0.040516944348695766, 'max_features': 'log2'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:02:57,257] Trial 6 finished with value: 0.9647124758148108 and parameters: {'n_estimators': 155, 'min_samples_leaf': 133, 'max_depth': 35, 'min_impurity_decrease': 0.023551191938288887, 'ccp_alpha': 0.02790255467106135, 'max_features': 'log2'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:02:59,107] Trial 12 finished with value: 0.9563935720784085 and parameters: {'n_estimators': 134, 'min_samples_leaf': 71, 'max_depth': 32, 'min_impurity_decrease': 0.07386325712397508, 'ccp_alpha': 0.04247373370885785, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:03:01,972] Trial 15 finished with value: 0.958316180391087 and parameters: {'n_estimators': 74, 'min_samples_leaf': 28, 'max_depth': 12, 'min_impurity_decrease': 0.07995677897063508, 'ccp_alpha': 0.02095983220104765, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:03:03,637] Trial 13 finished with value: 0.9562608606597843 and parameters: {'n_estimators': 125, 'min_samples_leaf': 34, 'max_depth': 11, 'min_impurity_decrease': 0.06705180589743594, 'ccp_alpha': 0.04255746654625242, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:03:03,916] Trial 14 finished with value: 0.956670168438678 and parameters: {'n_estimators': 109, 'min_samples_leaf': 13, 'max_depth': 22, 'min_impurity_decrease': 0.08191352040587191, 'ccp_alpha': 0.017738733430157645, 'max_features': 'log2'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00:03:10,337] Trial 16 finished with value: 0.9566246545875051 and parameters: {'n_estimators': 213, 'min_samples_leaf': 122, 'max_depth': 23, 'min_impurity_decrease': 0.06072926361989986, 'ccp_alpha': 0.04276915103688105, 'max_features': 'log2'}. Best is trial 3 with value: 0.9838668885756813.
# [I 2024-12-10 00
 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:24,905] Trial 451 finished with value: 0.984045327396165 and parameters: {'n_estimators': 261, 'min_samples_leaf': 120, 'max_depth': 20, 'min_impurity_decrease': 8.809071354766107e-05, 'ccp_alpha': 0.002839228910263345, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:28,356] Trial 455 finished with value: 0.9759010690852543 and parameters: {'n_estimators': 235, 'min_samples_leaf': 117, 'max_depth': 20, 'min_impurity_decrease': 0.0021270734345926476, 'ccp_alpha': 0.0022607855870702583, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:28,683] Trial 454 finished with value: 0.9775504840711854 and parameters: {'n_estimators': 262, 'min_samples_leaf': 117, 'max_depth': 20, 'min_impurity_decrease': 0.001517935137252176, 'ccp_alpha': 0.0026257055492866464, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:33,959] Trial 456 finished with value: 0.9856814080935251 and parameters: {'n_estimators': 235, 'min_samples_leaf': 119, 'max_depth': 20, 'min_impurity_decrease': 1.1366172758978604e-05, 'ccp_alpha': 0.0017003754769855522, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:34,644] Trial 457 finished with value: 0.9854031331789338 and parameters: {'n_estimators': 235, 'min_samples_leaf': 116, 'max_depth': 21, 'min_impurity_decrease': 3.657788987446527e-05, 'ccp_alpha': 0.0018645634897610228, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:34,693] Trial 459 finished with value: 0.9778691545092032 and parameters: {'n_estimators': 233, 'min_samples_leaf': 26, 'max_depth': 21, 'min_impurity_decrease': 0.0015864997551549428, 'ccp_alpha': 0.0012713133908135526, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:37,863] Trial 458 finished with value: 0.9849648835413961 and parameters: {'n_estimators': 234, 'min_samples_leaf': 118, 'max_depth': 20, 'min_impurity_decrease': 4.5968032232240515e-05, 'ccp_alpha': 0.0013735899660673528, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:44,065] Trial 460 finished with value: 0.9868193324451462 and parameters: {'n_estimators': 247, 'min_samples_leaf': 27, 'max_depth': 20, 'min_impurity_decrease': 9.677352343227176e-05, 'ccp_alpha': 0.0012912124634796092, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:44,849] Trial 462 finished with value: 0.9864819499152455 and parameters: {'n_estimators': 247, 'min_samples_leaf': 27, 'max_depth': 20, 'min_impurity_decrease': 9.74209417613938e-05, 'ccp_alpha': 0.001460918611276576, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:45,214] Trial 461 finished with value: 0.9870915475719747 and parameters: {'n_estimators': 259, 'min_samples_leaf': 27, 'max_depth': 20, 'min_impurity_decrease': 7.506213835717089e-05, 'ccp_alpha': 0.0011220005942587112, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:48,281] Trial 463 finished with value: 0.9869918928811385 and parameters: {'n_estimators': 247, 'min_samples_leaf': 27, 'max_depth': 20, 'min_impurity_decrease': 8.570831103253656e-05, 'ccp_alpha': 0.0013048454057541412, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:51,023] Trial 465 finished with value: 0.9781232568638175 and parameters: {'n_estimators': 260, 'min_samples_leaf': 26, 'max_depth': 20, 'min_impurity_decrease': 0.0015607372077483615, 'ccp_alpha': 0.0008935128570887049, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:21:52,016] Trial 464 finished with value: 0.9840192581386922 and parameters: {'n_estimators': 246, 'min_samples_leaf': 117, 'max_depth': 22, 'min_impurity_decrease': 0.0001966882954443478, 'ccp_alpha': 0.0011975057288096964, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00
 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:17,680] Trial 480 finished with value: 0.9742056534444347 and parameters: {'n_estimators': 242, 'min_samples_leaf': 27, 'max_depth': 19, 'min_impurity_decrease': 0.00418758452289205, 'ccp_alpha': 0.0009848502337497498, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:19,083] Trial 481 finished with value: 0.9738404174755186 and parameters: {'n_estimators': 230, 'min_samples_leaf': 27, 'max_depth': 21, 'min_impurity_decrease': 0.0042864553874959665, 'ccp_alpha': 0.001052913501156565, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:19,646] Trial 482 finished with value: 0.973246464128766 and parameters: {'n_estimators': 241, 'min_samples_leaf': 35, 'max_depth': 19, 'min_impurity_decrease': 0.004550567147839401, 'ccp_alpha': 0.00098458216992891, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:20,427] Trial 483 finished with value: 0.9742072631114381 and parameters: {'n_estimators': 241, 'min_samples_leaf': 109, 'max_depth': 19, 'min_impurity_decrease': 0.004098223424858197, 'ccp_alpha': 0.0011105555268046908, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:23,564] Trial 484 finished with value: 0.9757397189121866 and parameters: {'n_estimators': 229, 'min_samples_leaf': 35, 'max_depth': 19, 'min_impurity_decrease': 0.002316675871468965, 'ccp_alpha': 0.000870215308889173, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:25,077] Trial 485 finished with value: 0.976329203768228 and parameters: {'n_estimators': 242, 'min_samples_leaf': 36, 'max_depth': 19, 'min_impurity_decrease': 0.0021560292753575326, 'ccp_alpha': 0.0007503354983898387, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:25,332] Trial 486 finished with value: 0.9759434738221303 and parameters: {'n_estimators': 231, 'min_samples_leaf': 27, 'max_depth': 21, 'min_impurity_decrease': 0.002140965318574993, 'ccp_alpha': 0.0007826664779067116, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:26,054] Trial 487 finished with value: 0.9748404845258417 and parameters: {'n_estimators': 230, 'min_samples_leaf': 133, 'max_depth': 19, 'min_impurity_decrease': 0.002618904184616245, 'ccp_alpha': 0.0008267678703668985, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:29,253] Trial 488 finished with value: 0.9761569005115573 and parameters: {'n_estimators': 240, 'min_samples_leaf': 134, 'max_depth': 19, 'min_impurity_decrease': 0.0020609831954859913, 'ccp_alpha': 0.00010120185658232242, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:31,170] Trial 490 finished with value: 0.9760886331791635 and parameters: {'n_estimators': 242, 'min_samples_leaf': 27, 'max_depth': 21, 'min_impurity_decrease': 0.0022457949361920837, 'ccp_alpha': 0.0001744646586166155, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:31,344] Trial 489 finished with value: 0.9763771080093447 and parameters: {'n_estimators': 242, 'min_samples_leaf': 132, 'max_depth': 21, 'min_impurity_decrease': 0.0018962069005735837, 'ccp_alpha': 0.00012713048126006266, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:32,030] Trial 491 finished with value: 0.9763895674289738 and parameters: {'n_estimators': 241, 'min_samples_leaf': 26, 'max_depth': 21, 'min_impurity_decrease': 0.002102467679798818, 'ccp_alpha': 0.00010538022544408665, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:33,340] Trial 492 finished with value: 0.9566363080255104 and parameters: {'n_estimators': 238, 'min_samples_leaf': 25, 'max_depth': 21, 'min_impurity_decrease': 0.06383735718660342, 'ccp_alpha': 0.00031670955094784624, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:37,121] Trial 493 finished with value: 0.9765295487559179 and parameters: {'n_estimators': 238, 'min_samples_leaf': 24, 'max_depth': 21, 'min_impurity_decrease': 0.00196397982912297, 'ccp_alpha': 9.898443521188204e-05, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:37,258] Trial 494 finished with value: 0.9761731671036418 and parameters: {'n_estimators': 239, 'min_samples_leaf': 132, 'max_depth': 21, 'min_impurity_decrease': 0.0020847264022527353, 'ccp_alpha': 0.0003255221557842226, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:37,919] Trial 495 finished with value: 0.9763285194875335 and parameters: {'n_estimators': 236, 'min_samples_leaf': 132, 'max_depth': 21, 'min_impurity_decrease': 0.0019184992561693428, 'ccp_alpha': 4.8592264074741754e-05, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:39,254] Trial 496 finished with value: 0.9763438974332126 and parameters: {'n_estimators': 236, 'min_samples_leaf': 132, 'max_depth': 21, 'min_impurity_decrease': 0.002101207417279489, 'ccp_alpha': 1.7089739757221271e-06, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:42,729] Trial 497 finished with value: 0.976467501948363 and parameters: {'n_estimators': 236, 'min_samples_leaf': 132, 'max_depth': 21, 'min_impurity_decrease': 0.0020523215273251364, 'ccp_alpha': 5.360112074908794e-05, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:42,812] Trial 498 finished with value: 0.975825435402295 and parameters: {'n_estimators': 237, 'min_samples_leaf': 133, 'max_depth': 21, 'min_impurity_decrease': 0.0022920806303148456, 'ccp_alpha': 0.00019661214347160556, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# [I 2024-12-10 00:22:47,492] Trial 499 finished with value: 0.992114588083688 and parameters: {'n_estimators': 237, 'min_samples_leaf': 23, 'max_depth': 21, 'min_impurity_decrease': 1.6166674960886916e-05, 'ccp_alpha': 0.0001429870960063949, 'max_features': 'log2'}. Best is trial 399 with value: 0.9926164253084658.
# Accuracy: 0.9926164253084658
# Best hyperparameters: {'n_estimators': 239, 'min_samples_leaf': 23, 'max_depth': 19, 'min_impurity_decrease': 1.8926482416876284e-05, 'ccp_alpha': 8.958898882577499e-05, 'max_features': 'log2'}

# %%
# best_rf_hpo = RandomForestClassifier(random_state=42, **study.best_params)
# best_rf_hpo.fit(train_df[input_variables], train_df['target_flag'])

# Plotting the learning curve
best_rf_hpo = RandomForestClassifier(n_estimators=33,
                                              max_depth=2,
                                              min_samples_leaf=2,
                                              ccp_alpha=5e-15,
                                              min_impurity_decrease=7e-2,
                                              class_weight = 'balanced',
                                              random_state=42)

train_sizes, train_scores, val_scores = learning_curve(
    best_rf_hpo,
    train_df[input_variables],
    train_df['target_flag'],
    cv=3,
    scoring='roc_auc',
    n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10)
)

plt.figure()
plt.plot(train_sizes, train_scores.mean(axis=1), label='Training score')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation score')
plt.xlabel('Training set size')
plt.ylabel('Score')
plt.legend()
plt.show()

# %%
# optuna.visualization.plot_param_importances(study)
# optuna.visualization.plot_optimization_history(study).show()
# optuna.visualization.plot_param_importances(study).show()
# optuna.visualization.plot_parallel_coordinate(study).show()
# optuna.visualization.plot_slice(study).show()

# %%
test_df=test_df.copy()

# %%
test_df
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 288      288       1        18              3     0       0    False        5
# 289      289       1        18              3     0      15    False        5
# 290      290       1        18              3     0      30    False        5
# 291      291       1        18              3     0      45    False        5
# 292      292       1        18              3     1       0    False        5
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89659  93164      11       194              3    22      45    False        0
# 89660  93165      11       194              3    23       0    False        0
# 89661  93166      11       194              3    23      15    False        0
# 89662  93167      11       194              3    23      30    False        0
# 89663  93168      11       194              3    23      45    False        0
#
#                ke      hupx  afrr_fel     afrr_le  mfrr_fel  mfrr_le  \
# 288    818.432049  254.4823    0.0000 -166.681833       0.0      0.0
# 289    821.300604  254.4823    3.7986  -25.764100       0.0      0.0
# 290    821.300418  254.4823    0.0000  -52.983133       0.0      0.0
# 291    821.300604  254.4823    0.0000 -115.675467       0.0      0.0
# 292    827.623523  251.2670    0.0000 -189.880167       0.0      0.0
# ...           ...       ...       ...         ...       ...      ...
# 89659  798.111149  245.0325   48.5940   -4.068233       0.0      0.0
# 89660  955.757579  242.8421    7.5478  -23.976433       0.0      0.0
# 89661  955.062473  242.8421   70.2754   -0.058900       0.0      0.0
# 89662  798.423227  242.8421   13.5954   -8.259433       0.0      0.0
# 89663  797.800393  242.8421   10.8498  -11.153800       0.0      0.0
#
#              afrr  solar_becsult_dayahead  rendszerterheles_terv  target_flag  \
# 288   -277.150007                     0.0            6449.113965          1.0
# 289     15.072000                     0.0            6358.788545          1.0
# 290   -159.524560                     0.0            6264.255005          1.0
# 291   -225.485493                     0.0            6148.678605          1.0
# 292   -300.647673                     0.0            6143.636545          1.0
# ...           ...                     ...                    ...          ...
# 89659  255.125000                     0.0            5290.121743          1.0
# 89660   34.992160                     0.0            5260.683360          0.0
# 89661  331.860320                     0.0            5233.595753          0.0
# 89662  145.118240                     0.0            5208.690177          1.0
# 89663  120.896280                     0.0            5185.924820          1.0
#
#        target_reg train_test_validation
# 288     76.721089                  test
# 289     67.264315                  test
# 290     67.264929                  test
# 291     67.264315                  test
# 292     37.729526                  test
# ...           ...                   ...
# 89659  118.173067                  test
# 89660 -407.460437                  test
# 89661 -405.168878                  test
# 89662  111.224239                  test
# 89663  113.277540                  test
#
# [17952 rows x 20 columns]

# %%
best_rf_hpo.fit(train_df[input_variables], train_df['target_flag'])
# Out:
# RandomForestClassifier(ccp_alpha=5e-15, class_weight='balanced', max_depth=2,
#                        min_impurity_decrease=0.07, min_samples_leaf=2,
#                        n_estimators=33, random_state=42)

# %%
test_df['tipp_C1']=best_rf_hpo.predict_proba(test_df[input_variables])[:,1]

# %%
test_df
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 288      288       1        18              3     0       0    False        5
# 289      289       1        18              3     0      15    False        5
# 290      290       1        18              3     0      30    False        5
# 291      291       1        18              3     0      45    False        5
# 292      292       1        18              3     1       0    False        5
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89659  93164      11       194              3    22      45    False        0
# 89660  93165      11       194              3    23       0    False        0
# 89661  93166      11       194              3    23      15    False        0
# 89662  93167      11       194              3    23      30    False        0
# 89663  93168      11       194              3    23      45    False        0
#
#                ke      hupx  ...     afrr_le  mfrr_fel  mfrr_le        afrr  \
# 288    818.432049  254.4823  ... -166.681833       0.0      0.0 -277.150007
# 289    821.300604  254.4823  ...  -25.764100       0.0      0.0   15.072000
# 290    821.300418  254.4823  ...  -52.983133       0.0      0.0 -159.524560
# 291    821.300604  254.4823  ... -115.675467       0.0      0.0 -225.485493
# 292    827.623523  251.2670  ... -189.880167       0.0      0.0 -300.647673
# ...           ...       ...  ...         ...       ...      ...         ...
# 89659  798.111149  245.0325  ...   -4.068233       0.0      0.0  255.125000
# 89660  955.757579  242.8421  ...  -23.976433       0.0      0.0   34.992160
# 89661  955.062473  242.8421  ...   -0.058900       0.0      0.0  331.860320
# 89662  798.423227  242.8421  ...   -8.259433       0.0      0.0  145.118240
# 89663  797.800393  242.8421  ...  -11.153800       0.0      0.0  120.896280
#
#        solar_becsult_dayahead  rendszerterheles_terv  target_flag  target_reg  \
# 288                       0.0            6449.113965          1.0   76.721089
# 289                       0.0            6358.788545          1.0   67.264315
# 290                       0.0            6264.255005          1.0   67.264929
# 291                       0.0            6148.678605          1.0   67.264315
# 292                       0.0            6143.636545          1.0   37.729526
# ...                       ...                    ...          ...         ...
# 89659                     0.0            5290.121743          1.0  118.173067
# 89660                     0.0            5260.683360          0.0 -407.460437
# 89661                     0.0            5233.595753          0.0 -405.168878
# 89662                     0.0            5208.690177          1.0  111.224239
# 89663                     0.0            5185.924820          1.0  113.277540
#
#        train_test_validation   tipp_C1
# 288                     test  0.844956
# 289                     test  0.844956
# 290                     test  0.844956
# 291                     test  0.844956
# 292                     test  0.844956
# ...                      ...       ...
# 89659                   test  0.611768
# 89660                   test  0.383278
# 89661                   test  0.127034
# 89662                   test  0.651458
# 89663                   test  0.654401
#
# [17952 rows x 21 columns]

# %%
"""
test_df['tipp_R1']=test_df['tipp_R1']-minX
maxX = test_df['tipp_R1'].max()
test_df['tipp_R1']=test_df['tipp_R1']/maxX
"""
# Out:
# "\ntest_df['tipp_R1']=test_df['tipp_R1']-minX\nmaxX = test_df['tipp_R1'].max()\ntest_df['tipp_R1']=test_df['tipp_R1']/maxX\n"

# %%
#test_df['tipp_R1'].describe()

# %%
roc_auc_score(test_df['target_flag'],test_df['tipp_C1'])
# Out:
# np.float64(0.9765023681160758)

# %%
for i in [0,1]:
    cdf = df[df['target_flag']==i]
    cdf['target_reg'].hist(bins=100)
plt.legend(['0','1'])

# %%
df['target_reg'].hist(bins=100)
# Out:
# <Axes: >

# %%
submit_df = submit_df.copy()
submit_df
# Out:
#        rowID  season  periodID  day_in_period  hour  minute  holyday  weekday  \
# 384      384       1        18              4     0       0    False        6
# 385      385       1        18              4     0      15    False        6
# 386      386       1        18              4     0      30    False        6
# 387      387       1        18              4     0      45    False        6
# 388      388       1        18              4     1       0    False        6
# ...      ...     ...       ...            ...   ...     ...      ...      ...
# 89755  93260      11       194              4    22      45    False        1
# 89756  93261      11       194              4    23       0    False        1
# 89757  93262      11       194              4    23      15    False        1
# 89758  93263      11       194              4    23      30    False        1
# 89759  93264      11       194              4    23      45    False        1
#
#        ke  hupx  afrr_fel  afrr_le  mfrr_fel  mfrr_le  afrr  \
# 384   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 385   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 386   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 387   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 388   NaN   NaN       NaN      NaN       NaN      NaN   NaN
# ...    ..   ...       ...      ...       ...      ...   ...
# 89755 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89756 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89757 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89758 NaN   NaN       NaN      NaN       NaN      NaN   NaN
# 89759 NaN   NaN       NaN      NaN       NaN      NaN   NaN
#
#        solar_becsult_dayahead  rendszerterheles_terv  target_flag  target_reg  \
# 384                       0.0            5269.072857          NaN         NaN
# 385                       0.0            5254.072107          NaN         NaN
# 386                       0.0            5236.946580          NaN         NaN
# 387                       0.0            5228.023347          NaN         NaN
# 388                       0.0            5238.872100          NaN         NaN
# ...                       ...                    ...          ...         ...
# 89755                     0.0            5256.726477          NaN         NaN
# 89756                     0.0            5228.971040          NaN         NaN
# 89757                     0.0            5203.779573          NaN         NaN
# 89758                     0.0            5180.754317          NaN         NaN
# 89759                     0.0            5159.795830          NaN         NaN
#
#       train_test_validation
# 384                  submit
# 385                  submit
# 386                  submit
# 387                  submit
# 388                  submit
# ...                     ...
# 89755                submit
# 89756                submit
# 89757                submit
# 89758                submit
# 89759                submit
#
# [17952 rows x 20 columns]

# %%
submit_df['prediction'] = best_rf_hpo.predict_proba(submit_df[input_variables])[:, 1]

# %%
submit_df=submit_df[['rowID','prediction']]

# %%
submit_df
# Out:
#        rowID  prediction
# 384      384    0.844956
# 385      385    0.844956
# 386      386    0.844956
# 387      387    0.844956
# 388      388    0.844956
# ...      ...         ...
# 89755  93260    0.844956
# 89756  93261    0.844956
# 89757  93262    0.844956
# 89758  93263    0.844956
# 89759  93264    0.844956
#
# [17952 rows x 2 columns]

# %%
current_time = datetime.datetime.now()

time_string = current_time.strftime("%Y%m%d_%H%M%S")

filename = f"prediction_datas/hpo_{time_string}.csv"

submit_df.to_csv(filename, index=False)

# %%
run_server(db_storage)
# Out:
# Bottle v0.13.2 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.
# 127.0.0.1 - - [10/Dec/2024 00:39:37] "GET /api/studies/37?after=100 HTTP/1.1" 200 3631
# 127.0.0.1 - - [10/Dec/2024 00:39:38] "GET /api/studies/36?after=100 HTTP/1.1" 200 3011
# 127.0.0.1 - - [10/Dec/2024 00:39:39] "GET /dashboard/studies/35 HTTP/1.1" 200 4145
# 127.0.0.1 - - [10/Dec/2024 00:39:40] "GET /dashboard/studies/32 HTTP/1.1" 200 4145
# 127.0.0.1 - - [10/Dec/2024 00:39:41] "GET /dashboard/studies/31 HTTP/1.1" 200 4145
